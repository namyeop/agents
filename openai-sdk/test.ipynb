# %%
from agents import Agent, Runner, SQLiteSession, function_tool
from agents.extensions.visualization import draw_graph

session = SQLiteSession('session-1', 'test.db')

@function_tool
def get_weather():
  return 30

agent = Agent(
    name="ExampleAgent",
    instructions="This is an example agent.",
    tools=[
        get_weather,
    ]
)

draw_graph(agent)

# runner = await Runner.run(agent, "What's my name?", session=session)

# print(runner.final_output)
